# %% [markdown]
# # Questions
#
# * What's the operational cost difference between:
#   Databricks: Managing Runtime versions, coordinating protocol upgrades, testing compatibility.
#   Snowflake: (answer is ..... "zero")
# * If a customer has 200 tables with ZORDER optimization, what happens when Databricks recommends migrating to liquid clustering? What's the migration path, and who owns that work?, A migration within the same platform (... not bad 🥹)?
# * What information is stored in the _delta_log/ directory, and why does it matter for compatibility?
# * How does this differ from how Snowflake manages table metadata?
# * When you enable deletion vectors on a Delta table, what changes in the protocol version, and which Runtime versions can no longer access the table?
#
# * Liquid clustering requires Runtime 13.3+, deletion vectors, row tracking, and v2 checkpoints. Why can't Databricks just make this the default for all new tables?
