# %% [markdown]
# # Questions
# * Where does query planning happen in a Spark cluster?
# * Where does the metadata computation actually happen?
# * What happens if a Databricks cluster goes down while updating metadata?
# * What story do they tell about operational complexity?
# * If Databricks is moving away from manual OPTIMIZE/ZORDER commands toward automatic Liquid Clustering, what does that tell you about their long-term architectural strategy?
# Are they trying to become more like Snowflake's automatic optimization model?
#   * The ongoing operational burden of keeping up with platform changes?
#   * Databricks' architectural stability?
#   * The learning curve investment they'll face again?
#
# * Why do you think Databricks felt compelled to build Serverless SQL as a separate offering?
